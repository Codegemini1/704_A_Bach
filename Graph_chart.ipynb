# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x = 'total_bill', y = 'tip', data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = 'total_bill', y = 'tip', data = df.head(10))
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = 'total_bill', y = 'tip', data = df.head(10))
plt.title('Line Chart of Tips total Bill of 10 Records')
plt.show()

# %%
sns.barplot(x = 'day', y = 'total_bill' , data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.barplot(df['smoker'].value_counts())
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'], bins=19)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Analysis on Tips Dataset

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data = df)

# %%
df['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data= df , hue = 'smoker')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data= df , hue = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data= df , hue = 'day')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data= df , style = 'size')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data= df , style = 'day')

# %%
sns.relplot(x = 'total_bill', y = 'tip' , data= df , style = 'size' , hue = 'smoker')

# %%
# Titanic Dataset
