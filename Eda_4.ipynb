# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cleaned_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating   Reviews        Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1     159.0  19000000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9     967.0  14000000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7   87510.0         8.7   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5  215644.0  25000000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3     967.0         2.8    100000  Free    0.0
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews        Size  Installs  Type  Price Content Rating  \
# 0    159.0  19000000.0     10000  Free    0.0       Everyone
# 1    967.0  14000000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
#
#    Month  year
# 0      1  2018
# 1      1  2018

# %%
cat_col = df.dtypes[df.dtypes=='object'].index

# %%
cat_col
# Out:
# Index(['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %% [markdown]
# # countplot

# %% [raw]
# # Optional
# for i in cat_col:
#     plt.figure(figsize=(10,4))
#     plt.title('Coutplot')
#     sns.countplot(x = df[i], palette='Set2')
#     plt.xticks(rotation=45)
#     plt.tight_layout()

# %%
plt.figure(figsize=(10,4))
plt.title('Coutplot')
sns.countplot(x = df['Type'], palette='Set2')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
plt.figure(figsize=(10,4))
plt.title('Coutplot')
sns.countplot(x = df['Content Rating'], palette='Set1')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
df['Category'].value_counts().plot.pie(y = df['Category'], figsize = (15,16), autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Solve QUestions

# %% [markdown]
# # We have to find out top 10 Categories ?

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# ...

# %%
cat_data = pd.DataFrame(df['Category'].value_counts())

# %%
df['Category'].value_counts().reset_index()
# Out:
#                Category  count
# 0                FAMILY   1972
# 1                  GAME   1144
# 2                 TOOLS    843
# 3               MEDICAL    463
# 4              BUSINESS    460
# 5          PRODUCTIVITY    424
# 6       PERSONALIZATION    392
# 7         COMMUNICATION    387
# 8                SPORTS    384
# 9             LIFESTYLE    382
# 10              FINANCE    366
# 11   HEALTH_AND_FITNESS    341
# 12          PHOTOGRAPHY    335
# 13               SOCIAL    295
# 14   NEWS_AND_MAGAZINES    283
# 15             SHOPPING    260
# 16     TRAVEL_AND_LOCAL    258
# 17               DATING    234
# 18  BOOKS_AND_REFERENCE    231
# 19        VIDEO_PLAYERS    175
# 20            EDUCATION    156
# 21        ENTERTAINMENT    149
# 22  MAPS_AND_NAVIGATION    137
# 23       FOOD_AND_DRINK    127
# 24       HOUSE_AND_HOME     88
# 25    AUTO_AND_VEHICLES     85
# 26   LIBRARIES_AND_DEMO     85
# 27              WEATHER     82
# 28       ART_AND_DESIGN     65
# ...

# %%
cat_data
# Out:
#                      count
# Category
# FAMILY                1972
# GAME                  1144
# TOOLS                  843
# MEDICAL                463
# BUSINESS               460
# PRODUCTIVITY           424
# PERSONALIZATION        392
# COMMUNICATION          387
# SPORTS                 384
# LIFESTYLE              382
# FINANCE                366
# HEALTH_AND_FITNESS     341
# PHOTOGRAPHY            335
# SOCIAL                 295
# NEWS_AND_MAGAZINES     283
# SHOPPING               260
# TRAVEL_AND_LOCAL       258
# DATING                 234
# BOOKS_AND_REFERENCE    231
# VIDEO_PLAYERS          175
# EDUCATION              156
# ENTERTAINMENT          149
# MAPS_AND_NAVIGATION    137
# FOOD_AND_DRINK         127
# HOUSE_AND_HOME          88
# AUTO_AND_VEHICLES       85
# LIBRARIES_AND_DEMO      85
# WEATHER                 82
# ART_AND_DESIGN          65
# EVENTS                  64
# PARENTING               60
# COMICS                  60
# BEAUTY                  53

# %%
cat_data.head(10)
# Out:
#                  count
# Category
# FAMILY            1972
# GAME              1144
# TOOLS              843
# MEDICAL            463
# BUSINESS           460
# PRODUCTIVITY       424
# PERSONALIZATION    392
# COMMUNICATION      387
# SPORTS             384
# LIFESTYLE          382

# %%
plt.figure(figsize=(15,6))
sns.barplot(x =cat_data.index[:10], y = 'count', data = cat_data[:10])
plt.title('Top 10 Categories Wise App Installs')
plt.xticks(rotation=90)
plt.show()

# %%
cat_data[:10]
# Out:
#                  count
# Category
# FAMILY            1972
# GAME              1144
# TOOLS              843
# MEDICAL            463
# BUSINESS           460
# PRODUCTIVITY       424
# PERSONALIZATION    392
# COMMUNICATION      387
# SPORTS             384
# LIFESTYLE          382

# %%
cat_data.index[:10]
# Out:
# Index(['FAMILY', 'GAME', 'TOOLS', 'MEDICAL', 'BUSINESS', 'PRODUCTIVITY',
#        'PERSONALIZATION', 'COMMUNICATION', 'SPORTS', 'LIFESTYLE'],
#       dtype='object', name='Category')

# %%
cat_data[:10]
# Out:
#                  count
# Category
# FAMILY            1972
# GAME              1144
# TOOLS              843
# MEDICAL            463
# BUSINESS           460
# PRODUCTIVITY       424
# PERSONALIZATION    392
# COMMUNICATION      387
# SPORTS             384
# LIFESTYLE          382

# %% [markdown]
# # Top 5 Categories based on install numbers

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000  Free    0.0       Everyone
# 1     967.0  14000000.0    500000  Free    0.0       Everyone
# 2   87510.0         8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25000000.0  50000000  Free    0.0           Teen
# 4     967.0         2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df.groupby('Category')['Installs'].sum()
# Out:
# Category
# ART_AND_DESIGN           124338100
# AUTO_AND_VEHICLES         53130211
# BEAUTY                    27197050
# BOOKS_AND_REFERENCE     1921469576
# BUSINESS                1001914865
# COMICS                    56086150
# COMMUNICATION          32647276251
# DATING                   264310807
# EDUCATION                871452000
# ENTERTAINMENT           2869160000
# EVENTS                    15973161
# FAMILY                 10258263505
# FINANCE                  876648734
# FOOD_AND_DRINK           273898751
# GAME                   35086024415
# HEALTH_AND_FITNESS      1583072512
# HOUSE_AND_HOME           168712461
# LIBRARIES_AND_DEMO        62995910
# LIFESTYLE                537643539
# MAPS_AND_NAVIGATION      724281890
# MEDICAL                   53257437
# NEWS_AND_MAGAZINES      7496317760
# PARENTING                 31521110
# PERSONALIZATION         2325494782
# PHOTOGRAPHY            10088247655
# PRODUCTIVITY           14176091369
# ...

# %%
df.groupby('Type')['Installs'].sum()
# Out:
# Type
# Free    167560477406
# Paid        72956081
# Name: Installs, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000  Free    0.0       Everyone
# 1     967.0  14000000.0    500000  Free    0.0       Everyone
# 2   87510.0         8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25000000.0  50000000  Free    0.0           Teen
# 4     967.0         2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df.groupby('Category')['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   35086024415
# COMMUNICATION          32647276251
# PRODUCTIVITY           14176091369
# SOCIAL                 14069867902
# TOOLS                  11452771915
# FAMILY                 10258263505
# PHOTOGRAPHY            10088247655
# NEWS_AND_MAGAZINES      7496317760
# TRAVEL_AND_LOCAL        6868887146
# VIDEO_PLAYERS           6222002720
# SHOPPING                3247848785
# ENTERTAINMENT           2869160000
# PERSONALIZATION         2325494782
# BOOKS_AND_REFERENCE     1921469576
# SPORTS                  1751174498
# HEALTH_AND_FITNESS      1583072512
# BUSINESS                1001914865
# FINANCE                  876648734
# EDUCATION                871452000
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                537643539
# WEATHER                  426100520
# FOOD_AND_DRINK           273898751
# DATING                   264310807
# HOUSE_AND_HOME           168712461
# ART_AND_DESIGN           124338100
# ...

# %%
df.groupby('Category')['Installs'].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   35086024415
# COMMUNICATION          32647276251
# PRODUCTIVITY           14176091369
# SOCIAL                 14069867902
# TOOLS                  11452771915
# FAMILY                 10258263505
# PHOTOGRAPHY            10088247655
# NEWS_AND_MAGAZINES      7496317760
# TRAVEL_AND_LOCAL        6868887146
# VIDEO_PLAYERS           6222002720
# SHOPPING                3247848785
# ENTERTAINMENT           2869160000
# PERSONALIZATION         2325494782
# BOOKS_AND_REFERENCE     1921469576
# SPORTS                  1751174498
# HEALTH_AND_FITNESS      1583072512
# BUSINESS                1001914865
# FINANCE                  876648734
# EDUCATION                871452000
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                537643539
# WEATHER                  426100520
# FOOD_AND_DRINK           273898751
# DATING                   264310807
# HOUSE_AND_HOME           168712461
# ART_AND_DESIGN           124338100
# ...

# %%
cat_installs = df.groupby('Category')['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
cat_installs
# Out:
#                Category     Installs
# 0                  GAME  35086024415
# 1         COMMUNICATION  32647276251
# 2          PRODUCTIVITY  14176091369
# 3                SOCIAL  14069867902
# 4                 TOOLS  11452771915
# 5                FAMILY  10258263505
# 6           PHOTOGRAPHY  10088247655
# 7    NEWS_AND_MAGAZINES   7496317760
# 8      TRAVEL_AND_LOCAL   6868887146
# 9         VIDEO_PLAYERS   6222002720
# 10             SHOPPING   3247848785
# 11        ENTERTAINMENT   2869160000
# 12      PERSONALIZATION   2325494782
# 13  BOOKS_AND_REFERENCE   1921469576
# 14               SPORTS   1751174498
# 15   HEALTH_AND_FITNESS   1583072512
# 16             BUSINESS   1001914865
# 17              FINANCE    876648734
# 18            EDUCATION    871452000
# 19  MAPS_AND_NAVIGATION    724281890
# 20            LIFESTYLE    537643539
# 21              WEATHER    426100520
# 22       FOOD_AND_DRINK    273898751
# 23               DATING    264310807
# ...

# %%
cat_installs.head()
# Out:
#         Category     Installs
# 0           GAME  35086024415
# 1  COMMUNICATION  32647276251
# 2   PRODUCTIVITY  14176091369
# 3         SOCIAL  14069867902
# 4          TOOLS  11452771915

# %%
plt.figure(figsize=(15,5))
sns.barplot(x =cat_installs['Category'].head(), y = 'Installs', data = cat_installs[:5])
plt.title('Top 10 Categories Wise App Installs')
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000000.0     10000  Free    0.0       Everyone
# 1     967.0  14000000.0    500000  Free    0.0       Everyone
# 2   87510.0         8.7   5000000  Free    0.0       Everyone
# 3  215644.0  25000000.0  50000000  Free    0.0           Teen
# 4     967.0         2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
# Top 5 App install each category

# %%
df.groupby(['Category', 'App'])['Installs'].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9739         WEATHER                                      Yahoo Weather
# 9740         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9741         WEATHER                                     Yandex.Weather
# 9742         WEATHER                         weather - weather forecast
# 9743         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
all_cat_install = df.groupby(['Category', 'App'])['Installs'].sum().reset_index()

# %%
all_cat_install =  all_cat_install.sort_values('Installs', ascending=False)

# %%
all_cat_install
# Out:
#              Category                                           App  \
# 4852             GAME                                Subway Surfers
# 7507     PRODUCTIVITY                                  Google Drive
# 7999           SOCIAL                                     Instagram
# 7160      PHOTOGRAPHY                                 Google Photos
# 1065    COMMUNICATION                                      Hangouts
# ...               ...                                           ...
# 2230           FAMILY                     Command & Conquer: Rivals
# 6918  PERSONALIZATION  Popsicle Launcher for Android P 9.0 launcher
# 547          BUSINESS                                    CX Network
# 7674     PRODUCTIVITY                                 cronometra-br
# 53     ART_AND_DESIGN                        Test Application DT 02
#
#         Installs
# 4852  6000000000
# 7507  4000000000
# 7999  4000000000
# 7160  4000000000
# 1065  4000000000
# ...          ...
# 2230           0
# ...

# %%
all_cat_install['Category'] == 'GAME'
# Out:
# 4852     True
# 7507    False
# 7999    False
# 7160    False
# 1065    False
#         ...
# 2230    False
# 6918    False
# 547     False
# 7674    False
# 53      False
# Name: Category, Length: 9744, dtype: bool

# %%
all_cat_install[all_cat_install['Category'] == 'GAME']
# Out:
#      Category                App    Installs
# 4852     GAME     Subway Surfers  6000000000
# 4245     GAME   Candy Crush Saga  3000000000
# 4881     GAME       Temple Run 2  3000000000
# 4707     GAME                Pou  1500000000
# 4659     GAME     My Talking Tom  1000000000
# ...       ...                ...         ...
# 4305     GAME  D+H Reaction Wall           1
# 4175     GAME   Bi-Tank Ads Free           1
# 4652     GAME            Mu.F.O.           1
# 4729     GAME           Ra Ga Ba           1
# 4972     GAME          YAKALA AY           1
#
# [960 rows x 3 columns]

# %%
all_cat_install[all_cat_install['Category'] == 'GAME'].head()
# Out:
#      Category               App    Installs
# 4852     GAME    Subway Surfers  6000000000
# 4245     GAME  Candy Crush Saga  3000000000
# 4881     GAME      Temple Run 2  3000000000
# 4707     GAME               Pou  1500000000
# 4659     GAME    My Talking Tom  1000000000

# %%
all_cat_install[all_cat_install['Category'] == 'PRODUCTIVITY'].head()
# Out:
#           Category              App    Installs
# 7507  PRODUCTIVITY     Google Drive  4000000000
# 7505  PRODUCTIVITY  Google Calendar  1500000000
# 7444  PRODUCTIVITY          Dropbox  1500000000
# 7552  PRODUCTIVITY   Microsoft Word  1500000000
# 7414  PRODUCTIVITY      Cloud Print   500000000

# %%
all_cat_install[all_cat_install['Category'] == 'SOCIAL'].head()
# Out:
#      Category            App    Installs
# 7999   SOCIAL      Instagram  4000000000
# 8064   SOCIAL       Snapchat  2000000000
# 7963   SOCIAL       Facebook  2000000000
# 7988   SOCIAL        Google+  2000000000
# 7965   SOCIAL  Facebook Lite  1000000000

# %%
each_catehgory = df['Category'].unique()

# %%
for i in each_catehgory:
    print(all_cat_install[all_cat_install['Category'] == i].head().reset_index())
    print('_'*80)
# Out:
#    index        Category                                                App  \
# 0     48  ART_AND_DESIGN                              Sketch - Draw & Paint
# 1     55  ART_AND_DESIGN                         Textgram - write on photos
# 2     62  ART_AND_DESIGN                                       ibis Paint X
# 3     52  ART_AND_DESIGN                     Tattoo Name On My Photo Editor
# 4      9  ART_AND_DESIGN  Canva: Poster, banner, card maker & graphic de...
#
#    Installs
# 0  50000000
# 1  20000000
# 2  10000000
# 3  10000000
# 4  10000000
# ________________________________________________________________________________
#    index           Category  \
# 0     70  AUTO_AND_VEHICLES
# 1     69  AUTO_AND_VEHICLES
# 2    100  AUTO_AND_VEHICLES
# 3    134  AUTO_AND_VEHICLES
# 4    140  AUTO_AND_VEHICLES
#
#                                                  App  Installs
# 0                      AutoScout24 - used car finder  10000000
# ...
